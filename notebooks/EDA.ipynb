# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import os

# %%
#RAW_CSV_PATH = os.path.join(os.path.dirname(__file__), os.pardir, "data", "raw", "michelin_my_maps.csv")
RAW_CSV_PATH = "/Users/albertfranquet/Repos/michelin-map/data/raw/michelin_my_maps.csv"
df = pd.read_csv(RAW_CSV_PATH)

# %%
df.Award.unique(), df.GreenStar.unique()
# Out:
# (array(['3 Stars', 'Selected Restaurants', '1 Star', '2 Stars',
#         'Bib Gourmand'], dtype=object),
#  array([0, 1]))

# %%
df.columns
# Out:
# Index(['Name', 'Address', 'Location', 'Price', 'Cuisine', 'Longitude',
#        'Latitude', 'PhoneNumber', 'Url', 'WebsiteUrl', 'Award', 'GreenStar',
#        'FacilitiesAndServices', 'Description'],
#       dtype='object')

# %%
df.head(1)
# Out:
#       Name                                         Address          Location  \
# 0  ES:SENZ  Mietenkamer Straße 65, Grassau, 83224, Germany  Grassau, Germany
#
#   Price                   Cuisine  Longitude  Latitude   PhoneNumber  \
# 0  €€€€  Creative, Modern Cuisine  12.465618  47.78563  4.986414e+11
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/bayern/grassau/r...
#
#                       WebsiteUrl    Award  GreenStar  \
# 0  https://www.das-achental.com/  3 Stars          0
#
#                              FacilitiesAndServices  \
# 0  Air conditioning,Car park,Interesting wine list
#
#                                          Description
# 0  From the get-go, the stage is set in grand sty...

# %%
df.WebsiteUrl
# Out:
# 0                            https://www.das-achental.com/
# 1                              https://schreiberei-muc.de/
# 2        https://www.traube-tonbach.de/restaurants-bar/...
# 3                      https://www.victors-fine-dining.de/
# 4                          https://www.restaurant-aqua.com
#                                ...
# 21905                     https://www.tavernakyclades.com/
# 21906                   https://vertfrais.squarespace.com/
# 21907                               https://mambopalma.es/
# 21908                           http://www.villacorallo.it
# 21909                                  https://mearkas.nl/
# Name: WebsiteUrl, Length: 21910, dtype: object
